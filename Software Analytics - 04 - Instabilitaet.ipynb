# %%
import pandas as pd 
import pygal as pg
from string import Template
from IPython.core.display import display, HTML

# %load_ext cypher
# %config CypherMagic.uri='http://neo4j:neo@localhost:7474/db/data'

# %%
base_html = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
  </head>
  <body>
    <figure>
      {rendered_chart}
    </figure>
  </body>
</html>
"""

# %% [markdown]
# * Robert C. Martin definiert Komplexitätsmetriken für Packages
#   * Anwendung kann auch für Klassen oder Module erfolgen (im folgenden zusammengefasst als Komponente)
#
#
# * Efferent Coupling (Ce)
#   * Anzahl der ausgehenden Abhängigkeiten (Fan-Out) einer Komponente
# * Afferent Coupling (Ca)
#   * Anzahl der eingehenden Abhängigkeiten (Fan-In) einer Komponente
# * Instabilität (I) = Ce / (Ce + Ca)
#   * Stabilität gegenüber Änderungen an anderen Komponenten (geringer = stabiler)
#   * Aber: Je stabiler desto schwerer zu ändern da viele abhängige Komponenten
# * Abstraktheit (A) = Na / Nc
#   * Anteil abstrakter (Methoden/Klassen) an Gesamtheit der Komponente
# * Distanz (D) = |A + I - 1|
#   * Abstand vom optimalen Verhältnis zwischen Abstraktheit und Instabilität (höher = schlechter)

# %% [markdown]
# * Zone of Pain
#   * Stabil (I klein) und Konkret (A klein)
#     * Änderungen an diesen Komponenten führen zu vielen Änderungen in abhängigen Komponenten
# * Zone of Uselessnes
#   * Instabil (I groß) und Abstract (A groß)
#     * Bereitgestellte abstrakte Komponenten finden keine Verwendung

# %%
instability_query = %cypher MATCH (t:Type:Shopizer) \
                            OPTIONAL MATCH (t)-[:DEPENDS_ON]->(d:Type:Shopizer) \
                            WITH t, count(d) AS EfferentCoupling \
                            OPTIONAL MATCH (e)-[:DEPENDS_ON]->(t) \
                            WITH t, EfferentCoupling, count(e) AS AfferentCoupling \
                            WHERE EfferentCoupling + AfferentCoupling > 0 \
                            RETURN t.fqn AS Type, t.name AS Name, toFloat(EfferentCoupling) / (EfferentCoupling + AfferentCoupling) AS Instability \
                            ORDER BY Instability DESC
instability_df = instability_query.get_dataframe()

abstractness_query = %cypher MATCH (t:Type:Shopizer)-[:DECLARES]->(m:Method) \
                             WITH t, count(m) AS Total \
                             OPTIONAL MATCH (t)-[:DECLARES]->(m:Method{abstract: true}) \
                             WITH t, toFloat(count(m)) / Total AS Abstractness \
                             RETURN t.fqn AS Type, t.name AS Name, Abstractness \
                             ORDER BY Abstractness DESC
abstractness_df = abstractness_query.get_dataframe()

distance_df = pd.merge(instability_df, abstractness_df, how='outer', on = ['Type','Name'])
distance_df = distance_df.fillna(0)

distance_df
# Out:
# 1121 rows affected.
# 1111 rows affected.
#                                                    Type  \
# 0     com.salesmanager.core.model.customer.connectio...
# 1     com.salesmanager.core.model.order.filehistory....
# 2     com.salesmanager.core.model.payments.BasicPayment
# 3     com.salesmanager.core.business.configuration.d...
# 4     com.salesmanager.core.business.configuration.P...
# ...                                                 ...
# 1146  com.salesmanager.shop.store.security.SocialCus...
# 1147           com.salesmanager.shop.tags.ActiveLinkTag
# 1148  com.salesmanager.shop.utils.AdminAccessDeniedH...
# 1149       com.salesmanager.shop.utils.AppConfiguration
# 1150           com.salesmanager.shop.utils.TokenizeTool
#
#                             Name  Instability  Abstractness
# 0                 UserConnection          1.0           0.0
# 1                    FileHistory          1.0           0.0
# 2                   BasicPayment          1.0           0.0
# 3                       DbConfig          1.0           0.0
# 4        ProcessorsConfiguration          1.0           0.0
# ...                          ...          ...           ...
# 1146  SocialCustomerServicesImpl          0.0           0.0
# 1147               ActiveLinkTag          0.0           0.0
# 1148    AdminAccessDeniedHandler          0.0           0.0
# 1149            AppConfiguration          0.0           0.0
# 1150                TokenizeTool          0.0           0.0
#
# [1151 rows x 4 columns]

# %%
distance_df['Distance'] = abs(distance_df.Instability + distance_df.Abstractness - 1)
distance_df = distance_df.sort_values('Distance', ascending=False)

# Entfernen reiner Utility-Klassen (Abstractness == 0, Instability == 0) da Senken
stackedBar_distance_df = distance_df[(distance_df.Abstractness > 0) & (distance_df.Instability > 0)]
stackedBar_distance_df = stackedBar_distance_df[0:30]

# %%
stacked_bar_chart = pg.StackedBar(show_legend=True, human_readable=True, fill=False, x_label_rotation=45, truncate_label=-1)
stacked_bar_chart.title = 'Robert C. Martin Metriken'
stacked_bar_chart.x_labels = stackedBar_distance_df['Name'].tolist()
stacked_bar_chart.add('Abstractness', stackedBar_distance_df['Abstractness'].tolist())
stacked_bar_chart.add('Instability', stackedBar_distance_df['Instability'].tolist())
stacked_bar_chart.add('Distance', stackedBar_distance_df['Distance'].tolist())
display(HTML(base_html.format(rendered_chart=stacked_bar_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-03-08--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318{background-color:rgba(249,249,249,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 path,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 rect,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .graph{fill:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 text.no_data{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .title{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .line{stroke:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis text.major{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y .guides:hover .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .line-graph .axis.x .guides:hover .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .ci{stroke:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .reactive.active,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .ci .reactive.active{stroke-width:1.5}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .series text{fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .tooltip .value{font-size:1.5em}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .bound{font-size:.5em}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-0,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-1,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-2,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .text-overlay .color-0 text{fill:black}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .text-overlay .color-1 text{fill:black}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .text-overlay .color-2 text{fill:black}
# #chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 text.no_data{text-anchor:middle}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .guide.line{fill:none}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .centered{text-anchor:middle}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .title{text-anchor:middle}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .legends .legend text{fill-opacity:1}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.x text{text-anchor:middle}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y text{text-anchor:end}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y text[transform].backwards{text-anchor:start}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y2 text{text-anchor:start}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y2 text[transform].backwards{text-anchor:end}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .guide.line{stroke-dasharray:4,4}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .major.guide.line{stroke-dasharray:6,6}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .horizontal .axis.y .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .horizontal .axis.y2 .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .vertical .axis.x .guide.line{opacity:0}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .horizontal .axis.always_show .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y .guides:hover .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.y2 .guides:hover .guide.line,#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis.x .guides:hover .guide.line{opacity:1}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .axis .guides:hover text{opacity:1}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .nofill{fill:none}#chart-6e9e4f9d-4db3-4410-a06f-7d9dfc900318 .subtle-fill{fill-opacity:.2}#chart-6e9e4f9d-4db3-4410-a06f-

# %%
type_distance_doc = []
for _id in distance_df.T:
    data = distance_df.T[_id]
    values = {'value': (data.Abstractness, data.Instability), 'label': data.Type}
    type_distance_doc.append(values)

# %%
xy_chart = pg.XY(stroke=False, x_title='Abstractness', y_title='Instability')
xy_chart.title = 'Robert C. Martin Distance'
xy_chart.add('Abstractness to Instability', type_distance_doc)
xy_chart.add('Optimum', [(0, 1), (1, 0)], stroke=True)
xy_chart.add('Zone of Pain', [(0, 0.3), (0.3, 0)], stroke=True)
xy_chart.add('Zone of Uselesness', [(1, 0.7), (0.7, 1)], stroke=True)
display(HTML(base_html.format(rendered_chart=xy_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-03-08--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0{background-color:rgba(249,249,249,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 path,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 rect,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .graph{fill:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 text.no_data{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .title{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .line{stroke:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis text.major{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y .guides:hover .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .line-graph .axis.x .guides:hover .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .ci{stroke:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .reactive.active,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .ci .reactive.active{stroke-width:1.5}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .series text{fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .tooltip .value{font-size:1.5em}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .bound{font-size:.5em}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-0,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-1,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-2,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-3,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .text-overlay .color-0 text{fill:black}#chart-21ebcc33-bd7f-444b-8a9b ...
# #chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 text.no_data{text-anchor:middle}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .guide.line{fill:none}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .centered{text-anchor:middle}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .title{text-anchor:middle}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .legends .legend text{fill-opacity:1}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.x text{text-anchor:middle}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y text{text-anchor:end}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y text[transform].backwards{text-anchor:start}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y2 text{text-anchor:start}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y2 text[transform].backwards{text-anchor:end}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .guide.line{stroke-dasharray:4,4}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis .major.guide.line{stroke-dasharray:6,6}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .horizontal .axis.y .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .horizontal .axis.y2 .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .vertical .axis.x .guide.line{opacity:0}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .horizontal .axis.always_show .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y .guides:hover .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.y2 .guides:hover .guide.line,#chart-21ebcc33-bd7f-444b-8a9b-f72353c2a5a0 .axis.x .guides:hover .guide.line{opacity:1}#chart-21ebcc33-bd

# %% [markdown]
# ### Welche fachlichen Module sind potentielle Problemquellen?

# %%
module_instability_query = %cypher MATCH (bC1:BoundedContext) \
                                   WITH bC1 \
                                   MATCH (bC1)-[:CONTAINS]->(t:Type:Shopizer)-[:DEPENDS_ON]->(d:Type:Shopizer)<-[:CONTAINS]-(bC2:BoundedContext) \
                                   WHERE bC1 <> bC2 \
                                   WITH bC1, count(d) AS EfferentCoupling \
                                   MATCH (bC1)-[:CONTAINS]->(t:Type:Shopizer)<-[:DEPENDS_ON]-(d:Type:Shopizer)<-[:CONTAINS]-(bC2:BoundedContext) \
                                   WHERE bC1 <> bC2 \
                                   WITH bC1, EfferentCoupling, count(d) AS AfferentCoupling \
                                   WITH bC1, toFloat(EfferentCoupling) / (EfferentCoupling + AfferentCoupling) AS Instability \
                                   RETURN bC1.name AS Name, Instability \
                                   ORDER BY Instability DESC
module_instability_df = module_instability_query.get_dataframe()

module_abstractness_query = %cypher MATCH (bC:BoundedContext)-[:CONTAINS]->(t:Type:Shopizer) \
                                    WITH bC, count(t) AS Total \
                                    OPTIONAL MATCH (bC)-[:CONTAINS]->(t:Type:Shopizer) \
                                    WHERE t:Interface OR exists(t.abstract) \
                                    WITH bC, toFloat(count(t)) / Total AS Abstractness \
                                    RETURN bC.name AS Name, Abstractness \
                                    ORDER BY Abstractness DESC 
module_abstractness_df = module_abstractness_query.get_dataframe()

module_distance_df = pd.merge(module_instability_df, module_abstractness_df, how='outer', on = ['Name'])
module_distance_df = module_distance_df.fillna(0)

module_distance_doc = []
for _id in module_distance_df.T:
    data = module_distance_df.T[_id]
    values = {'value': (data.Abstractness, data.Instability), 'label': data.Name}
    module_distance_doc.append(values)
# Out:
# 14 rows affected.
# 14 rows affected.

# %%
xy_module_chart = pg.XY(stroke=False, x_title='Abstractness', y_title='Instability')
xy_module_chart.title = 'Robert C. Martin Distance'
xy_module_chart.add('Abstractness to Instability', module_distance_doc)
xy_module_chart.add('Optimum', [(0, 1), (1, 0)], stroke=True)
xy_module_chart.add('Zone of Pain', [(0, 0.3), (0.3, 0)], stroke=True)
xy_module_chart.add('Zone of Uselesness', [(1, 0.7), (0.7, 1)], stroke=True)
display(HTML(base_html.format(rendered_chart=xy_module_chart.render(is_unicode=True))))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" class="pygal-chart" id="chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896" viewBox="0 0 800 600" xmlns="http://www.w3.org/2000/svg"><!--Generated with pygal 2.4.0 (etree) ©Kozea 2012-2016 on 2021-03-08--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896{background-color:rgba(249,249,249,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 path,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 rect,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .graph{fill:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 text.no_data{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .title{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .line{stroke:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis text.major{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y .guides:hover .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .line-graph .axis.x .guides:hover .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .reactive{fill-opacity:.7;stroke-opacity:.8}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .ci{stroke:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .reactive.active,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .ci .reactive.active{stroke-width:1.5}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .series text{fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .tooltip .value{font-size:1.5em}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .bound{font-size:.5em}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-0,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-1,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-2,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-3,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .text-overlay .color-0 text{fill:black}#chart-19c0b8a0-b6db-4cf4-b680 ...
# #chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 text.no_data{text-anchor:middle}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .guide.line{fill:none}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .centered{text-anchor:middle}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .title{text-anchor:middle}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .legends .legend text{fill-opacity:1}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.x text{text-anchor:middle}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y text{text-anchor:end}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y text[transform].backwards{text-anchor:start}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y2 text{text-anchor:start}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y2 text[transform].backwards{text-anchor:end}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .guide.line{stroke-dasharray:4,4}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis .major.guide.line{stroke-dasharray:6,6}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .horizontal .axis.y .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .horizontal .axis.y2 .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .vertical .axis.x .guide.line{opacity:0}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .horizontal .axis.always_show .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y .guides:hover .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.y2 .guides:hover .guide.line,#chart-19c0b8a0-b6db-4cf4-b680-7ea7942eb896 .axis.x .guides:hover .guide.line{opacity:1}#chart-19c0b8a0-b6
