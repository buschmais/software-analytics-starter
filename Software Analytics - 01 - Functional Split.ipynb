# %%
import plotly.express as px
import pandas as pd
from string import Template
from pathlib import Path
from string import Template
from IPython.core.display import display, HTML

# %load_ext cypher
# %config CypherMagic.uri='http://neo4j:neo@localhost:7474/db/data'

# %%
from IPython.display import HTML, Javascript, display

# %%
# %%javascript
#     var script = document.createElement('script');
#     script.type = 'text/javascript';
#     script.src = '//cdnjs.cloudflare.com/ajax/libs/d3/4.13.0/d3.js';
#     document.head.appendChild(script);
#     console.log(window.d3)

# %%
# %%javascript
#     var script = document.createElement('script');
#     script.type = 'text/javascript';
#     script.src = '//cdnjs.cloudflare.com/ajax/libs/lodash.js/4.17.21/lodash.js';
#     document.head.appendChild(script);
#     console.log(window._)

# %%
display(HTML(filename='chord.css.html'))
# Out:
# <style>
#   #tooltip {
#     color: white;
#     opacity: .9;
#     background: #333;
#     padding: 5px;
#     border: 1px solid lightgrey;
#     border-radius: 5px;
#     position: absolute;
#     z-index: 10;
#     visibility: hidden;
#     white-space: nowrap;
#     pointer-events: none;
#     font-size: 1.3em;
#   }
#   #circle circle {
#     fill: none;
#     pointer-events: all;
#   }
#   path.group {
#     fill-opacity: .8;
#   }
#   path.chord {
#     fill-opacity: .8;
#     stroke: #000;
#     stroke-width: .25px;
#   }
#   #circle:hover path.fade {
#     display: none;
#   }
# </style>

# %% [markdown]
# # Analysing structures with Software Analytics

# %% [markdown]
# ## Question

# %% [markdown]
# <center>Into which functional components is the system split and how do they depend on each other?</center>

# %% [markdown]
# ## Data Sources

# %% [markdown]
# * Java structures of the Shopizer system scanned by jQAssistant and available in Neo4j
#
#
# * identification of functional components in the source code is required

# %% [markdown]
# ## Heuristics

# %% [markdown]
# * functional components are visible in the service layer (`com.salesmanager.core.business.services.<component>`)
#    * Packages with the same name in different parent packages are part of the same functional component

# %% [markdown]
# ## Validation

# %% [markdown]
# * graphical overview of the functional components and their dependencies
# * tabular overview of source code which could not be assigned to a functional component (for later post-processing)
#
#
# * review of the functional components happens after the presentation by domain experts
# * validation of functional dependencies for their correctness by domain experts
# * in case of issues identified: evaluation of the analysis or refactoring of the code

# %% [markdown]
# ## Implementation

# %% [markdown]
# * identification of functional components via sub packages in `com.salesmanager.core.business.services`
#    * enriching the graph with additional nodes per functional component (:BoundedContext)
#    * assignment of all Java types to the created:BoundedContext nodes va the package names [:CONTAINS]
#
#
# * aggregation of dependencies between types to the level of :BoundedContexts ([:DEPENDS_ON])
#    * number of dependencies (coupling) as property of the relation (weight)

# %%
# %%cypher
# // Identifying all Shopizer nodes (duplicates query from notebook 00)
# MATCH (artifact:Main:Artifact{group: "com.shopizer"})
# SET artifact:Shopizer
# WITH artifact
# MATCH (artifact)-[:CONTAINS]->(c)
# SET c:Shopizer
# Out:
# 0 rows affected.
# []

# %%
# %%cypher
# // Creating a node per functional component
# MATCH    (p:Package:Shopizer)-[:CONTAINS]->(bC:Package:Shopizer)
# WHERE    p.fqn = "com.salesmanager.core.business.services"
# WITH     collect(DISTINCT bC.name) AS boundedContexts
# UNWIND   boundedContexts AS boundedContext
# MERGE    (bC:BoundedContext {name: boundedContext})
# Out:
# 0 rows affected.
# []

# %%
# %%cypher
# // Assigning all types to their respective bounded contexts
# MATCH    (bC:BoundedContext),
#          (p:Package:Shopizer)-[:CONTAINS*]->(t:Type:Shopizer)
# WHERE    p.name = bC.name
# MERGE    (bC)-[:CONTAINS]->(t)
# RETURN   bC.name AS BoundedContext, count(t) AS Size
# ORDER BY Size DESC
# Out:
# 14 rows affected.
# [['catalog', 233],
#  ['customer', 107],
#  ['order', 103],
#  ['content', 58],
#  ['shipping', 52],
#  ['system', 48],
#  ['user', 41],
#  ['reference', 28],
#  ['common', 25],
#  ['shoppingcart', 21],
#  ['tax', 17],
#  ['payments', 15],
#  ['merchant', 14],
#  ['search', 13]]

# %%
# %%cypher
# // Enriching the dependencies between bounded contexts (without taking the data layer into account)
# MATCH  (bC1:BoundedContext)-[:CONTAINS]->(t1:Type:Shopizer),
#        (bC2:BoundedContext)-[:CONTAINS]->(t2:Type:Shopizer),
#        (t1)-[dep:DEPENDS_ON]->(t2)
# WHERE  NOT exists((t1)-[:ANNOTATED_BY]-()-[:OF_TYPE]->(:Type{fqn: 'javax.persistence.Entity'})) AND
#        NOT exists((t2)-[:ANNOTATED_BY]-()-[:OF_TYPE]->(:Type{fqn: 'javax.persistence.Entity'}))
# WITH   bC1, bC2, sum(dep.weight) AS weight
# MERGE  (bC1)-[:DEPENDS_ON{weight: weight}]->(bC2)
# Out:
# 0 rows affected.
# []

# %% [markdown]
# ## Results

# %%
# %%cypher
# // Proportional share of assigned classes
# MATCH (t:Type:Shopizer)
# WITH count(t) AS Total
# MATCH (:BoundedContext)-[:CONTAINS]->(t:Type:Shopizer)
# RETURN 100 * count(t) / Total AS Coverage
# Out:
# 1 rows affected.
# [[65]]

# %%
# %%cypher
# // Not assigned classes
# MATCH (p:Package)-[:CONTAINS*]->(t:Type:Shopizer)
# WHERE NOT EXISTS((:BoundedContext)-[:CONTAINS]->(t))
# RETURN p.fqn AS Package, count(DISTINCT t) AS Count
# ORDER BY Count DESC, Package ASC
# Out:
# 133 rows affected.
# [['com', 395],
#  ['com.salesmanager', 395],
#  ['com.salesmanager.shop', 314],
#  ['com.salesmanager.shop.store', 113],
#  ['com.salesmanager.core', 81],
#  ['com.salesmanager.core.business', 70],
#  ['com.salesmanager.shop.admin', 58],
#  ['com.salesmanager.shop.store.controller', 54],
#  ['com.salesmanager.shop.model', 45],
#  ['com.salesmanager.core.business.modules', 41],
#  ['com.salesmanager.shop.admin.controller', 40],
#  ['com.salesmanager.shop.utils', 32],
#  ['com.salesmanager.shop.store.api', 31],
#  ['com.salesmanager.core.business.modules.cms', 20],
#  ['com.salesmanager.shop.store.security', 18],
#  ['com.salesmanager.core.business.utils', 17],
#  ['com.salesmanager.shop.application', 17],
#  ['com.salesmanager.shop.store.api.v1', 17],
#  ['com.salesmanager.shop.application.config', 16],
#  ['com.salesmanager.shop.tags', 15],
#  ['com.salesmanager.shop.admin.controller.products', 14],
#  ['com.salesmanager.shop.model.entity', 12],
#  ['com.salesmanager.shop.model.references', 12],
#  ['com.salesmanager.shop.admin.model', 11],
#  ['com.salesmanager.shop.populator', 11],
#  ['com.salesmanager.core.business.modules.cms.impl', 10],
#  ['com.salesmanager.core.business.modules.cms.product', 10],
#  ['com.salesmanager.core.business.modules.email', 10],
#  ['com.salesmanager.shop.store.api.v1.product', 10],
#  ['com.salesmanager.shop.store.api.exception', 9],
#  ['com.salesmanager.shop.model.store', 8],
#  ['com.salesmanager.core.business.configuration', 7],
#  ['com.salesmanager.core.business.modules.integration', 7],
#  ['com.salesmanager.shop.admin.security', 7],
#  ['com.salesmanager.shop.store.facade', 7],
#  ['com.salesmanager.core.business.modules.integration.payment', 6],
#  ['com.salesmanager.core.business.modules.integration.payment.impl', 6],
#  ['com.salesmanager.core.modules', 6],
#  ['com.salesmanager.shop.model.shop', 6],
#  ['com.salesmanager.shop.store.controller.product', 6],
#  ['com.salesmanager.shop.validation', 6],
#  ['com.salesmanager.shop.mapper', 5],
#  ['com.salesmanager.shop.model.security', 5],
#  ['com.salesmanager.shop.store.api.v0', 5],
#  ['com.salesmanager.shop.admin.controller.customers', 4],
#  ['com.salesmanager.shop.admin.model.permission', 4],
#  ['com.salesmanager.shop.store.controller.product.facade', 4],
#  ['com.salesmanager.shop.store.controller.shoppingCart', 4],
#  ['com.salesmanager.shop.store.facade.product', 4],
#  ['com.salesmanager.shop.store.security.admin', 4],
#  ['com.salesmanager.core.business.constants', 3],
#  ['com.salesmanager.shop.admin.controller.configurations', 3],
#  ['com.salesmanager.shop.admin.controller.orders', 3],
#  ['com.salesmanager.shop.constants', 3],
#  ['com.salesmanager.shop.controller', 3],
#  ['com.salesmanager.shop.filter', 3],
#  ['com.salesmanager.shop.init', 3],
#  ['com.salesmanager.shop.init.data', 3],
#  ['com.salesmanager.shop.populator.shoppingCart', 3],
#  ['com.salesmanager.shop.store.controller.category', 3],
#  ['com.salesmanager.shop.store.controller.currency', 3],
#  ['com.salesmanager.shop.store.controller.currency.facade', 3],
#  ['com.salesmanager.shop.store.controller.store', 3],
#  ['com.salesmanager.shop.store.model', 3],
#  ['com.salesmanager.core.business.exception', 2],
#  ['com.salesmanager.core.business.modules.cart', 2],
#  ['com.salesmanager.core.business.modules.utils', 2],
#  ['com.salesmanager.core.business.utils.ajax', 2],
#  ['com.salesmanager.core.constants', 2],
#  ['com.salesmanager.core.model', 2],
#  ['com.salesmanager.core.modules.integration', 2],
#  ['com.salesmanager.core.modules.utils', 2],
#  ['com.salesmanager.shop.admin.model.orders', 2],
#  ['com.salesmanager.shop.admin.model.web', 2],
#  ['com.salesmanager.shop.mapper.inventory', 2],
#  ['com.salesmanager.shop.mapper.optin', 2],
#  ['com.salesmanager.shop.model.marketplace', 2],
#  ['com.salesmanager.shop.populator.manufacturer', 2],
#  ['com.salesmanager.shop.populator.references', 2],
#  ['com.salesmanager.shop.populator.store', 2],
#  ['com.salesmanager.shop.store.api.v0.product', 2],
#  ['com.salesmanager.shop.store.controller.country', 2],
#  ['com.salesmanager.shop.store.controller.country.facade', 2],
#  ['com.salesmanager.shop.store.controller.error', 2],
#  ['com.salesmanager.shop.store.controller.items', 2],
#  ['com.salesmanager.shop.store.controller.language', 2],
#  ['com.salesmanager.shop.store.controller.language.facade', 2],
#  ['com.salesmanager.shop.store.controller.marketplace', 2],
#  ['com.salesmanager.shop.store.controller.marketplace.facade', 2],
#  ['com.salesmanager.shop.store.controller.optin', 2],
#  ['com.salesmanager.shop.store.controller.security', 2],
#  ['com.salesmanager.shop.store.controller.security.facade', 2],
#  ['com.salesmanager.shop.store.controller.shoppingCart.facade', 2],
#  ['com.salesmanager.shop.store.controller.store.facade', 2],
#  ['com.salesmanager.shop.store.controller.zone', 2],
#  ['com.salesmanager.shop.store.controller.zone.facade', 2],
#  ['com.salesmanager.shop.store.model.filter', 2],
#  ['com.salesmanager.core.business.configuration.db', 1],
#  ['com.salesmanager.core.business.modules.cms.product.aws', 1],
#  ['com.salesmanager.core.business.modules.cms.product.gcp', 1],
#  ['com.salesmanager.core.business.modules.cms.product.infinispan', 1],
#  ['com.salesmanager.core.business.modules.cms.product.local', 1],
#  ['com.salesmanager.core.business.utils.query', 1],
#  ['com.salesmanager.core.model.generic', 1],
#  ['com.salesmanager.core.model.security', 1],
#  ['com.salesmanager.core.modules.constants', 1],
#  ['com.salesmanager.core.modules.integration.payment', 1],
#  ['com.salesmanager.core.modules.integration.payment.model', 1],
#  ['com.salesmanager.core.utils', 1],
#  ['com.salesmanager.shop.admin.controller.categories', 1],
#  ['com.salesmanager.shop.admin.model.digital', 1],
#  ['com.salesmanager.shop.admin.model.secutity', 1],
#  ['com.salesmanager.shop.admin.model.userpassword', 1],
#  ['com.salesmanager.shop.populator.security', 1],
#  ['com.salesmanager.shop.store.api.v0.category', 1],
#  ['com.salesmanager.shop.store.api.v0.store', 1],
#  ['com.salesmanager.shop.store.api.v0.utility', 1],
#  ['com.salesmanager.shop.store.api.v1.category', 1],
#  ['com.salesmanager.shop.store.api.v1.configurations', 1],
#  ['com.salesmanager.shop.store.api.v1.marketplace', 1],
#  ['com.salesmanager.shop.store.api.v1.references', 1],
#  ['com.salesmanager.shop.store.api.v1.security', 1],
#  ['com.salesmanager.shop.store.api.v1.shoppingCart', 1],
#  ['com.salesmanager.shop.store.api.v1.store', 1],
#  ['com.salesmanager.shop.store.controller.category.facade', 1],
#  ['com.salesmanager.shop.store.controller.items.facade', 1],
#  ['com.salesmanager.shop.store.controller.manufacturer', 1],
#  ['com.salesmanager.shop.store.controller.manufacturer.facade', 1],
#  ['com.salesmanager.shop.store.facade.category', 1],
#  ['com.salesmanager.shop.store.facade.items', 1],
#  ['com.salesmanager.shop.store.facade.manufacturer', 1],
#  ['com.salesmanager.shop.store.model.paging', 1],
#  ['com.salesmanager.shop.store.security.manager', 1]]

# %%
subdomainSize = %cypher MATCH (bC:BoundedContext),                            \
                       (p:Package:Shopizer)-[:CONTAINS*]->(t:Type:Shopizer)   \
                 WHERE p.name = bC.name                                       \
                 MERGE (bC)-[:CONTAINS]->(t)                                  \
                 RETURN bC.name AS  BoundedContext,                           \
                        count(DISTINCT t) AS Classes

df = subdomainSize.get_dataframe()
px.pie(df, values='Classes', names='BoundedContext', title='Bounded Context Sizes')
# Out:
# 14 rows affected.
# Figure({
#     'data': [{'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#               'hovertemplate': 'BoundedContext=%{label}<br>Classes=%{value}<extra></extra>',
#               'labels': array(['content', 'merchant', 'shipping', 'tax', 'order', 'common', 'system',
#                                'search', 'reference', 'catalog', 'user', 'customer', 'shoppingcart',
#                                'payments'], dtype=object),
#               'legendgroup': '',
#               'name': '',
#               'showlegend': True,
#               'type': 'pie',
#               'values': array([ 58,  14,  52,  17, 103,  25,  48,  13,  28, 215,  41, 107,  21,  15])}],
#     'layout': {'legend': {'tracegroupgap': 0}, 'template': '...', 'title': {'text': 'Bounded Context Sizes'}}
# })

# %%
# Dependencies between bounded contexts
bCRelations = %cypher MATCH (bC1:BoundedContext)-[d:DEPENDS_ON]->(bC2:BoundedContext) \
                      RETURN bC1.name AS Source, \
                             bC2.name AS Target, \
                             d.weight AS X_Count

bounded_context_connections = bCRelations.get_dataframe()
bounded_context_connections_csv = '\"' + bounded_context_connections.to_csv(index = False).replace("\r\n","\n").replace("\n","\\n") + '\"'
# Out:
# 82 rows affected.

# %%
chord_script = Template(Path('chord.js').read_text())

Javascript(chord_script.substitute(data=bounded_context_connections_csv))

# %% [markdown]
# ## Next Steps

# %% [markdown]
# * presentation of the results and discussion with domain experts
#    * if needed: modification of the analysis with more details
# * enriching the architecutre documentation with the information about the functional split
