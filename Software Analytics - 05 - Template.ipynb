# %%
from py2neo import Graph
graph = Graph('http://neo4j:neo@localhost:7474/db/data')

# %% [markdown]
# # Topic

# %% [markdown]
# ## Question

# %% [markdown]
# <center>What do I want to know?</center>

# %% [markdown]
# ## Data Sources

# %% [markdown]
# ## Heuristics

# %% [markdown]
# ## Validation

# %% [markdown]
# ## Implementation

# %% [markdown]
# ## Results

# %% [markdown]
# ## Next Steps
